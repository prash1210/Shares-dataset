# %%
cd D:\Prashant Documents\Seminar
# Out:
# D:\Prashant Documents\Seminar

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_excel("Shares_dataset.xlsx","Sheet1")
df
# Out:
#     Sr.No           Stock  Market Price  Market Cap (Cr)    EV (Cr)     PE  \
# 0       1             ITC        184.00        226238.00  359914.00  15.10
# 1       2             BEL         80.00         19504.00   21849.00  14.19
# 2       3             FCL         26.90           299.40     449.00  11.75
# 3       4             MUL         13.45            17.92     586.64   0.00
# 4       5        AGROPHOS         13.95            28.28     160.38   5.41
# 5       6             7NR         10.96            11.48      50.23   0.00
# 6       7      DARJEELING          4.92             1.50      28.05   4.24
# 7       8        ALOKTEXT         36.15          7991.00   24374.00   1.45
# 8       9         V guard        172.80          7400.00    6530.00  39.54
# 9      10         Havells        576.00         36114.00   28922.00  49.10
# 10     11    Asian Paints       1652.00        158473.00  142950.00  58.34
# ...

# %%
df.head()
# Out:
#    Sr.No     Stock  Market Price  Market Cap (Cr)    EV (Cr)     PE   P/B  \
# 0      1       ITC        184.00        226238.00  359914.00  15.10  3.94
# 1      2       BEL         80.00         19504.00   21849.00  14.19  2.11
# 2      3       FCL         26.90           299.40     449.00  11.75  1.82
# 3      4       MUL         13.45            17.92     586.64   0.00  0.13
# 4      5  AGROPHOS         13.95            28.28     160.38   5.41  0.82
#
#    Golden Ratio    EPS    ROE   ROCE  D/E      ICR    QR  Promoters Holding
# 0       59.4940  12.19  21.29  31.04  0.00  422.00  2.38                NaN
# 1       29.9409   5.64  20.47  25.46  0.00  207.00  1.09              51.14
# 2       21.3850   2.29  14.18  21.17  0.01   42.01  2.82              71.42
# 3        0.0000      0   3.04  18.95  1.83    1.16  1.21              73.93
# 4        4.4362   2.58   2.39  10.70  0.55    1.63  1.18                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr.No              16 non-null     int64
#  1   Stock              16 non-null     object
#  2   Market Price       16 non-null     float64
#  3   Market Cap (Cr)    16 non-null     float64
#  4   EV (Cr)            15 non-null     float64
#  5   PE                 16 non-null     float64
#  6   P/B                16 non-null     float64
#  7   Golden Ratio       16 non-null     float64
#  8   EPS                16 non-null     object
#  9   ROE                16 non-null     float64
#  10  ROCE               16 non-null     float64
#  11  D/E                16 non-null     float64
#  12  ICR                16 non-null     float64
#  13  QR                 16 non-null     float64
#  14  Promoters Holding  14 non-null     float64
# dtypes: float64(12), int64(1), object(2)
# ...

# %%
df.describe()
# Out:
#          Sr.No  Market Price  Market Cap (Cr)        EV (Cr)         PE  \
# count  16.0000     16.000000     1.600000e+01      15.000000  16.000000
# mean    8.8750    392.633125     1.062709e+05  100882.243333  19.374375
# std     5.3401    623.271328     2.936412e+05  247582.771147  20.048086
# min     1.0000      4.250000     1.500000e+00       0.000000   0.000000
# 25%     4.7500     13.825000     1.684100e+02     105.305000   5.117500
# 50%     8.5000     58.075000     7.695500e+03     654.350000  12.970000
# 75%    12.2500    388.275000     3.625775e+04   26648.000000  32.385000
# max    18.0000   1746.000000     1.180719e+06  926766.000000  58.340000
#
#              P/B  Golden Ratio        ROE       ROCE       D/E            ICR  \
# count  16.000000     16.000000  16.000000  16.000000  16.000000     16.000000
# mean    4.255625    186.327719  13.556875  19.913750   0.250625   5449.309375
# std     6.199858    352.384453  10.699975   9.579653   0.738913  21471.675298
# ...

# %%
df.corr()
# Out:
#                       Sr.No  Market Price  Market Cap (Cr)   EV (Cr)  \
# Sr.No              1.000000      0.378836         0.105879  0.034307
# Market Price       0.378836      1.000000         0.643072  0.599506
# Market Cap (Cr)    0.105879      0.643072         1.000000  0.981727
# EV (Cr)            0.034307      0.599506         0.981727  1.000000
# PE                 0.345068      0.769694         0.214922  0.183730
# P/B                0.319584      0.709526        -0.006710 -0.028894
# Golden Ratio       0.359379      0.728229        -0.019463 -0.053328
# ROE                0.298587      0.321181        -0.043806 -0.016720
# ROCE               0.052542      0.329397        -0.152741 -0.109226
# D/E                0.106293      0.011456         0.116510  0.122506
# ICR                0.453977     -0.166145        -0.096500 -0.111480
# QR                -0.296308     -0.241399        -0.221489 -0.175766
# Promoters Holding  0.057142      0.221774        -0.015208 -0.047898
#
# ...

# %%
sns.scatterplot(x='Golden Ratio',y='ROCE',data=df)
# Out:
# <AxesSubplot:xlabel='Golden Ratio', ylabel='ROCE'>

# %%
X = df[['Golden Ratio']]
y = df['ROCE']
print(X,y)
# Out:
#     Golden Ratio
# 0        59.4940
# 1        29.9409
# 2        21.3850
# 3         0.0000
# 4         4.4362
# 5         0.0000
# 6         1.3144
# 7         0.0000
# 8       292.9914
# 9       411.4580
# 10      935.7736
# 11       69.0000
# 12        3.5934
# 13     1130.1804
# 14        5.1300
# 15       16.5462 0     31.04
# 1     25.46
# 2     21.17
# 3     18.95
# 4     10.70
# 5      2.71
# 6     22.73
# 7     11.52
# 8     24.25
# 9     19.46
# 10    31.23
# 11    10.62
# 12    13.59
# 13    38.88
# 14    10.38
# 15    25.93
# Name: ROCE, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
X_train.shape
# Out:
# (11, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 15.264545202811682

# %%
model.coef_
# Out:
# array([0.0178687])

# %%
model.score(X_train,y_train)
# Out:
# 0.28301830432571706

# %%
y_pred = model.predict(X_train)

# %%
error= y_pred-y_train

# %%
rmse=np.sqrt(np.mean((error)**2))
rmse
# Out:
# 7.532845411613074

# %%
y_pred_test=model.predict(X_test)

# %%
test_error=y_pred_test-y_test

# %%
test_rmse=np.sqrt(np.mean((test_error)**2))
test_rmse
# Out:
# 6.073482692840961

# %%
GR = 15
predicted_ROCE = 0.01788493* GR + 16.58129
predicted_ROCE
# Out:
# 16.84956395

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
final_poly_converter=PolynomialFeatures(degree=1,include_bias=False)

# %%
final_model=LinearRegression()

# %%
final_model.fit(final_poly_converter.fit_transform(X),y)
# Out:
# LinearRegression()

# %%
from joblib import dump,load

# %%
dump(final_model, 'Shares_ROCE.joblib')
# Out:
# ['Shares_ROCE.joblib']

# %%
dump(final_poly_converter,"poly_converter.joblib")
# Out:
# ['poly_converter.joblib']
